# %%
import os
import sys
sys.path.append(['..'])
import time
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# import seaborn as sns
import ipyvolume

# %%
MAP = ['circut_spa', 'RaceTrack', 'RaceTrack2']
PATH = '../data/spawn_points'

# %%
for i in range(3):
    track = pd.read_csv(f'{PATH}/{MAP[i]}.csv')
    plt.figure(figsize=(13,10))
    plt.plot(track['x'], track['y'])
    plt.xlim([min(track['x'])-10, max(track['x'])+10])
    plt.ylim([min(track['y']-10), max(track['y']+10)])
    plt.show()
